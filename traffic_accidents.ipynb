# %%
import pandas as pd
import matplotlib.pyplot as plt
# Load the data using read_csv function
df = pd.read_csv('../data/raw/NYC_Accidents_2020.csv',delimiter=',', header=0, skiprows=3)

# %%
list(df.columns)
# Out:
# ['CRASH DATE',
#  'CRASH TIME',
#  'BOROUGH',
#  'ZIP CODE',
#  'LATITUDE',
#  'LONGITUDE',
#  'LOCATION',
#  'ON STREET NAME',
#  'CROSS STREET NAME',
#  'OFF STREET NAME',
#  'NUMBER OF PERSONS INJURED',
#  'NUMBER OF PERSONS KILLED',
#  'NUMBER OF PEDESTRIANS INJURED',
#  'NUMBER OF PEDESTRIANS KILLED',
#  'NUMBER OF CYCLIST INJURED',
#  'NUMBER OF CYCLIST KILLED',
#  'NUMBER OF MOTORIST INJURED',
#  'NUMBER OF MOTORIST KILLED',
#  'CONTRIBUTING FACTOR VEHICLE 1',
#  'CONTRIBUTING FACTOR VEHICLE 2',
#  'CONTRIBUTING FACTOR VEHICLE 3',
#  'CONTRIBUTING FACTOR VEHICLE 4',
#  'CONTRIBUTING FACTOR VEHICLE 5',
#  'COLLISION_ID',
#  'VEHICLE TYPE CODE 1',
#  'VEHICLE TYPE CODE 2',
#  'VEHICLE TYPE CODE 3',
#  'VEHICLE TYPE CODE 4',
#  'VEHICLE TYPE CODE 5']

# %%
df.head()
# Out:
#   CRASH DATE CRASH TIME   BOROUGH  ZIP CODE  LATITUDE  LONGITUDE  \
# 0    8/29/20   15:40:00     BRONX   10466.0  40.89210 -73.833760
# 1    8/29/20   21:00:00  BROOKLYN   11221.0  40.69050 -73.919914
# 2    8/29/20   18:20:00       NaN       NaN  40.81650 -73.946556
# 3    8/29/20    0:00:00     BRONX   10459.0  40.82472 -73.892960
# 4    8/29/20   17:10:00  BROOKLYN   11203.0  40.64989 -73.933890
#
#                      LOCATION   ON STREET NAME CROSS STREET NAME  \
# 0   POINT (-73.83376 40.8921)     PRATT AVENUE     STRANG AVENUE
# 1  POINT (-73.919914 40.6905)  BUSHWICK AVENUE   PALMETTO STREET
# 2  POINT (-73.946556 40.8165)         8 AVENUE               NaN
# 3  POINT (-73.89296 40.82472)              NaN               NaN
# 4  POINT (-73.93389 40.64989)              NaN               NaN
#
#        OFF STREET NAME  ...  CONTRIBUTING FACTOR VEHICLE 2  \
# 0                  NaN  ...                    Unspecified
# 1                  NaN  ...                    Unspecified
# ...

# %%
df.tail()
# Out:
#       CRASH DATE CRASH TIME    BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 74876     1/1/20   15:13:00      BRONX   10459.0  40.826810 -73.896510
# 74877     1/1/20    8:00:00   BROOKLYN   11235.0  40.582935 -73.959210
# 74878     1/1/20   11:36:00      BRONX   10461.0  40.848553 -73.830055
# 74879     1/1/20    1:45:00  MANHATTAN   10017.0  40.753624 -73.969440
# 74880     1/1/20   18:00:00     QUEENS   11367.0  40.726875 -73.830960
#
#                            LOCATION  ON STREET NAME CROSS STREET NAME  \
# 74876    POINT (-73.89651 40.82681)             NaN               NaN
# 74877   POINT (-73.95921 40.582935)             NaN               NaN
# 74878  POINT (-73.830055 40.848553)             NaN               NaN
# 74879   POINT (-73.96944 40.753624)  EAST 48 STREET          2 AVENUE
# 74880   POINT (-73.83096 40.726875)             NaN               NaN
#
#              OFF STREET NAME  ...   CONTRIBUTING FACTOR VEHICLE 2  \
# ...

# %%
df.sample(n=5)
# Out:
#       CRASH DATE CRASH TIME BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 26530    5/27/20   14:10:00     NaN       NaN  40.666348  -73.76093
# 65133    1/22/20   19:15:00   BRONX   10475.0  40.867996  -73.83134
# 48250    2/27/20   22:40:00     NaN       NaN        NaN        NaN
# 70289    1/11/20    3:40:00  QUEENS   11412.0  40.696648  -73.76175
# 66325    1/19/20   11:30:00     NaN       NaN        NaN        NaN
#
#                           LOCATION                   ON STREET NAME  \
# 26530  POINT (-73.76093 40.666348)                     BELT PARKWAY
# 65133  POINT (-73.83134 40.867996)                              NaN
# 48250                          NaN                   PELHAM PARKWAY
# 70289  POINT (-73.76175 40.696648)                FARMERS BOULEVARD
# 66325                          NaN  BROOKLYN QUEENS EXPRESSWAY RAMP
#
#               CROSS STREET NAME        OFF STREET NAME  ...  \
# 26530                       NaN                    NaN  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74881 entries, 0 to 74880
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   CRASH DATE                     74881 non-null  object
#  1   CRASH TIME                     74881 non-null  object
#  2   BOROUGH                        49140 non-null  object
#  3   ZIP CODE                       49134 non-null  float64
#  4   LATITUDE                       68935 non-null  float64
#  5   LONGITUDE                      68935 non-null  float64
#  6   LOCATION                       68935 non-null  object
#  7   ON STREET NAME                 55444 non-null  object
#  8   CROSS STREET NAME              35681 non-null  object
#  9   OFF STREET NAME                19437 non-null  object
#  10  NUMBER OF PERSONS INJURED      74881 non-null  int64
#  11  NUMBER OF PERSONS KILLED       74881 non-null  int64
# ...

# %% [markdown]
# BOROUGH should be categorical
# ZIP code should be string data type
# Crash Date and time should be date or timestap data types

# %%
df = df.drop(['VEHICLE TYPE CODE 5', 'VEHICLE TYPE CODE 4'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_35008\3175376194.py in <module>
# ----> 1 df = df.drop(['VEHICLE TYPE CODE 5', 'VEHICLE TYPE CODE 4'], axis=1)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
df.rename(columns={'CRASH DATE': 'DATE'}, inplace=True)
df.head()
# Out:
#       DATE CRASH TIME   BOROUGH  ZIP CODE  LATITUDE  LONGITUDE  \
# 0  8/29/20   15:40:00     BRONX   10466.0  40.89210 -73.833760
# 1  8/29/20   21:00:00  BROOKLYN   11221.0  40.69050 -73.919914
# 2  8/29/20   18:20:00       NaN       NaN  40.81650 -73.946556
# 3  8/29/20    0:00:00     BRONX   10459.0  40.82472 -73.892960
# 4  8/29/20   17:10:00  BROOKLYN   11203.0  40.64989 -73.933890
#
#                      LOCATION   ON STREET NAME CROSS STREET NAME  \
# 0   POINT (-73.83376 40.8921)     PRATT AVENUE     STRANG AVENUE
# 1  POINT (-73.919914 40.6905)  BUSHWICK AVENUE   PALMETTO STREET
# 2  POINT (-73.946556 40.8165)         8 AVENUE               NaN
# 3  POINT (-73.89296 40.82472)              NaN               NaN
# 4  POINT (-73.93389 40.64989)              NaN               NaN
#
#        OFF STREET NAME  ...  NUMBER OF CYCLIST INJURED  \
# 0                  NaN  ...                          0
# 1                  NaN  ...                          0
# ...

# %% [markdown]
# Removed these columns due to several missing values and also relevancy to the study I am doing.

# %%
#need to add rename or transform here

# %%
on_street_name = df['ON STREET NAME']
#remove missing vals
on_street_name = on_street_name.dropna()
#counts of streetname
street_counts = on_street_name.groupby(on_street_name).count()

#sort data descending
street_counts = street_counts.sort_values(ascending=False)

#print top 3
print(street_counts.head(3))
# Out:
# ON STREET NAME
# BELT PARKWAY                  1241
# LONG ISLAND EXPRESSWAY         745
# BROOKLYN QUEENS EXPRESSWAY     738
# Name: ON STREET NAME, dtype: int64

# %%
borough = df['BOROUGH']

#include missing values in other
borough = borough.fillna('Other')

#specify which boroughs we want
borough[~borough.isin(['MANHATTAN', 'BROOKLYN', 'QUEENS', 'BRONX'])] = 'Other'

#group data by count
borough_counts = borough.groupby(borough).count()

#plot
fig, ax = plt.subplots()
ax.pie(borough_counts, labels=borough_counts.index, autopct='%1.1f%%')
ax.set_title('Number of Accidents by Borough')
plt.show()

# %%
injuries = df[['BOROUGH', 'NUMBER OF PERSONS INJURED']]

#replace misssing valyes
injuries['NUMBER OF PERSONS INJURED'] = injuries['NUMBER OF PERSONS INJURED'].fillna(0)

#summary stats for nyc
all_stats = injuries['NUMBER OF PERSONS INJURED'].describe()

#summary stats for two boroughs. 
borough_stats = injuries[injuries['BOROUGH'].isin(['MANHATTAN', 'BROOKLYN'])].groupby('BOROUGH')['NUMBER OF PERSONS INJURED'].describe()

# Print the results
print("Summary Statistics for All of NYC:\n", all_stats)
print("\nSummary Statistics for Selected Boroughs:\n", borough_stats)
# Out:
# Summary Statistics for All of NYC:
#  count    74881.000000
# mean         0.366555
# std          0.726178
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max         15.000000
# Name: NUMBER OF PERSONS INJURED, dtype: float64
#
# Summary Statistics for Selected Boroughs:
#               count      mean       std  min  25%  50%  75%   max
# BOROUGH
# BROOKLYN   16907.0  0.356302  0.708303  0.0  0.0  0.0  1.0  15.0
# MANHATTAN   7353.0  0.292534  0.584037  0.0  0.0  0.0  0.0   5.0
# C:\Users\14153\AppData\Local\Temp\ipykernel_35008\3569737500.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   injuries['NUMBER OF PERSONS INJURED'] = injuries['NUMBER OF PERSONS INJURED'].fillna(0)

# %% [markdown]
# On average for every accident in New York City, about 3.6/10 people are injured or .36. Accidens in Brooklyn are lower than the average for the whole city. Meanwhile brooklyn is nearly equal to the average for NYC.

# %%
locations = df[['BOROUGH', 'LATITUDE', 'LONGITUDE']]

# Replace missing values with 'UNKNOWN'
locations['BOROUGH'] = locations['BOROUGH'].fillna('UNKNOWN')
locations['LATITUDE'] = locations['LATITUDE'].fillna(0)
locations['LONGITUDE'] = locations['LONGITUDE'].fillna(0)

# Create a scatter plot to show the accidents by borough
colors = {'BRONX': 'red', 'BROOKLYN': 'blue', 'MANHATTAN': 'green', 'QUEENS': 'orange', 'UNKNOWN': 'gray', 'STATEN ISLAND': 'purple'}
fig, ax = plt.subplots()
for borough in ['BRONX', 'BROOKLYN', 'MANHATTAN', 'QUEENS', 'STATEN ISLAND']:
    if borough != 'UNKNOWN':
        borough_locations = locations[locations['BOROUGH'] == borough]
        ax.scatter(borough_locations['LATITUDE'], borough_locations['LONGITUDE'], c=colors[borough], label=borough, alpha=0.5, s=1)
ax.legend()
ax.set_xlabel('Latitude')
ax.set_ylabel('Longitude')
ax.set_title('Accidents by Geo Location and Borough')

ax.set_ylim(-73 , -75)
ax.set_xlim(40.4 , 41)# set the y-axis limits
plt.show()
# Out:
# C:\Users\14153\AppData\Local\Temp\ipykernel_35008\2240267201.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   locations['BOROUGH'] = locations['BOROUGH'].fillna('UNKNOWN')
# C:\Users\14153\AppData\Local\Temp\ipykernel_35008\2240267201.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   locations['LATITUDE'] = locations['LATITUDE'].fillna(0)
# C:\Users\14153\AppData\Local\Temp\ipykernel_35008\2240267201.py:6: SettingWithCopyWarning:
# ...

# %%
df.describe()
# Out:
#            ZIP CODE      LATITUDE     LONGITUDE  NUMBER OF PERSONS INJURED  \
# count  49134.000000  68935.000000  68935.000000               74881.000000
# mean   10913.681585     40.689825    -73.843376                   0.366555
# std      515.069483      1.233368      2.234881                   0.726178
# min    10000.000000      0.000000    -74.253006                   0.000000
# 25%    10458.000000     40.667076    -73.958680                   0.000000
# 50%    11210.000000     40.716885    -73.916850                   0.000000
# 75%    11354.000000     40.789445    -73.862630                   1.000000
# max    11697.000000     40.912884      0.000000                  15.000000
#
#        NUMBER OF PERSONS KILLED  NUMBER OF PEDESTRIANS INJURED  \
# count              74881.000000                   74881.000000
# mean                   0.001923                       0.054740
# std                    0.047609                       0.237582
# ...

# %%
cols = ['NUMBER OF PERSONS INJURED', 'NUMBER OF PERSONS KILLED', 'NUMBER OF PEDESTRIANS INJURED', 'NUMBER OF CYCLIST INJURED', 'NUMBER OF MOTORIST INJURED', 'NUMBER OF PEDESTRIANS KILLED', 'NUMBER OF CYCLIST KILLED', 'NUMBER OF MOTORIST KILLED']

# Calculate covariance matrix
cov_matrix = df[cols].cov()

cov_matrix
# Out:
#                                NUMBER OF PERSONS INJURED  \
# NUMBER OF PERSONS INJURED                       0.527334
# NUMBER OF PERSONS KILLED                        0.000617
# NUMBER OF PEDESTRIANS INJURED                   0.042047
# NUMBER OF CYCLIST INJURED                       0.030986
# NUMBER OF MOTORIST INJURED                      0.454301
# NUMBER OF PEDESTRIANS KILLED                   -0.000047
# NUMBER OF CYCLIST KILLED                       -0.000044
# NUMBER OF MOTORIST KILLED                       0.000708
#
#                                NUMBER OF PERSONS KILLED  \
# NUMBER OF PERSONS INJURED                      0.000617
# NUMBER OF PERSONS KILLED                       0.002267
# NUMBER OF PEDESTRIANS INJURED                 -0.000052
# NUMBER OF CYCLIST INJURED                     -0.000071
# NUMBER OF MOTORIST INJURED                     0.000740
# NUMBER OF PEDESTRIANS KILLED                   0.000760
# ...

# %%
df.head()
# Out:
#       DATE CRASH TIME   BOROUGH  ZIP CODE  LATITUDE  LONGITUDE  \
# 0  8/29/20   15:40:00     BRONX   10466.0  40.89210 -73.833760
# 1  8/29/20   21:00:00  BROOKLYN   11221.0  40.69050 -73.919914
# 2  8/29/20   18:20:00       NaN       NaN  40.81650 -73.946556
# 3  8/29/20    0:00:00     BRONX   10459.0  40.82472 -73.892960
# 4  8/29/20   17:10:00  BROOKLYN   11203.0  40.64989 -73.933890
#
#                      LOCATION   ON STREET NAME CROSS STREET NAME  \
# 0   POINT (-73.83376 40.8921)     PRATT AVENUE     STRANG AVENUE
# 1  POINT (-73.919914 40.6905)  BUSHWICK AVENUE   PALMETTO STREET
# 2  POINT (-73.946556 40.8165)         8 AVENUE               NaN
# 3  POINT (-73.89296 40.82472)              NaN               NaN
# 4  POINT (-73.93389 40.64989)              NaN               NaN
#
#        OFF STREET NAME  ...  NUMBER OF CYCLIST INJURED  \
# 0                  NaN  ...                          0
# 1                  NaN  ...                          0
# ...

# %%
from calendar import month_abbr
import calendar

locations = locations[locations['CRASH DATE'].notnull()]

# get the month column by converting the date column to datetime format
locations['CRASH DATE'] = pd.to_datetime(locations['CRASH DATE'])
locations['MONTH'] = locations['CRASH DATE'].dt.month

# count the number of accidents for each month
month_counts = locations['MONTH'].value_counts()

# remove months with no accidents
month_counts = {k: v for k, v in month_counts.items() if k in range(1, 9)}

# get the abbreviated month names
month_names = [month_abbr[i] for i in month_counts.keys()]

# create a pandas DataFrame from the dictionary
df_month_counts = pd.DataFrame({'Month': month_names, 'Accidents': month_counts.values()})

# plot the bar chart using pandas plot method
df_month_counts.plot(kind='bar', x='Month', y='Accidents', legend=False)
plt.xlabel('Month')
plt.ylabel('Number of Accidents')
plt.title('Number of Accidents by Month')
plt.show()

# %% [markdown]
# it appear as the year progresses, the accidents seem to decline. This lull may be due to the lack of people outside due to the covid-19 virus habing been spread.
