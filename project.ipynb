# %% [markdown]
# Data set documented in previous assignment.

# %%
import pandas as pd

df = pd.read_csv('../data/raw/all_seasons.csv')

# %%
df = df.drop('Unnamed: 0', axis=1)

# %%
df.head()
# Out:
#          player_name team_abbreviation   age  player_height  player_weight  \
# 0      Dennis Rodman               CHI  36.0         198.12      99.790240
# 1  Dwayne Schintzius               LAC  28.0         215.90     117.933920
# 2       Earl Cureton               TOR  39.0         205.74      95.254320
# 3        Ed O'Bannon               DAL  24.0         203.20     100.697424
# 4        Ed Pinckney               MIA  34.0         205.74     108.862080
#
#                        college country draft_year draft_round draft_number  \
# 0  Southeastern Oklahoma State     USA       1986           2           27
# 1                      Florida     USA       1990           1           24
# 2                Detroit Mercy     USA       1979           3           58
# 3                         UCLA     USA       1995           1            9
# 4                    Villanova     USA       1985           1           10
#
# ...

# %%
count = df.college.nunique()
print("Unique values : "+ str(count))
# Out:
# Unique values : 347

# %%
import matplotlib.pyplot as plt

height=df['player_height']
plt.hist(height)
plt.xlabel('Height')
plt.ylabel('Number of Players')
plt.title('Height Distribution in the History of the NBA')
plt.show()

# %%
df['PRA'] = df['pts'] + df['reb'] + df['ast']
df.head()
# Out:
#          player_name team_abbreviation   age  player_height  player_weight  \
# 0      Dennis Rodman               CHI  36.0         198.12      99.790240
# 1  Dwayne Schintzius               LAC  28.0         215.90     117.933920
# 2       Earl Cureton               TOR  39.0         205.74      95.254320
# 3        Ed O'Bannon               DAL  24.0         203.20     100.697424
# 4        Ed Pinckney               MIA  34.0         205.74     108.862080
#
#                        college country draft_year draft_round draft_number  \
# 0  Southeastern Oklahoma State     USA       1986           2           27
# 1                      Florida     USA       1990           1           24
# 2                Detroit Mercy     USA       1979           3           58
# 3                         UCLA     USA       1995           1            9
# 4                    Villanova     USA       1985           1           10
#
# ...

# %%
stats = df[['player_height']]
all_stats = stats['player_height'].describe()
all_stats
# Out:
# count    12305.000000
# mean       200.611602
# std          9.146321
# min        160.020000
# 25%        193.040000
# 50%        200.660000
# 75%        208.280000
# max        231.140000
# Name: player_height, dtype: float64

# %%
plt.boxplot(height)
plt.ylabel('Height')
plt.title('Boxplot of height in the NBA')
plt.show()

# %% [markdown]
# We see the affect of height on the different areas of basketball. The average NBA player is 200 cm and the shortes was 160. It is a bell shaped curve that is fairly normal. we can see the quartiles are quite small relativly meaning there is a large center at the bell. I also created a new stat called PRA (points rebounds and assits). This is a common stat in basketball and I made it here to have a overall productivy measure of the players.
